# %% [markdown]
# <a href="https://colab.research.google.com/github/yanyoulin/llama.cpp-for-Warm-Up-lab/blob/main/lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/lab_chen/cpu
# Out:
# /content/drive/MyDrive/lab_chen/cpu

# %%
# !git clone https://github.com/ggerganov/llama.cpp
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 25502, done.
# remote: Counting objects: 100% (6886/6886), done.
# remote: Compressing objects: 100% (372/372), done.
# remote: Total 25502 (delta 6675), reused 6561 (delta 6514), pack-reused 18616
# Receiving objects: 100% (25502/25502), 47.57 MiB | 10.10 MiB/s, done.
# Resolving deltas: 100% (18125/18125), done.
# Updating files: 100% (666/666), done.

# %%
cd /content/drive/MyDrive/lab_chen/cpu/llama.cpp
# Out:
# /content/drive/MyDrive/lab_chen/cpu/llama.cpp

# %%
# !make
# Out:
# I ccache not found. Consider installing it for faster compilation.
# I llama.cpp build info:
# I UNAME_S:   Linux
# I UNAME_P:   x86_64
# I UNAME_M:   x86_64
# I CFLAGS:    -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion
# I CXXFLAGS:  -std=c++11 -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wmissing-declarations -Wmissing-noreturn -pthread  -march=native -mtune=native -Wno-array-bounds -Wno-format-truncation -Wextra-semi -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE
# I NVCCFLAGS: -std=c++11 -O3
# I LDFLAGS:
# I CC:        cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# I CXX:       c++ (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#
# ...

# %%
# !pip install llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 MB 13.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.4 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.2.76-cp310-cp310-linux_x86_64.whl size=3658144 sha256=02622e96a48584d0dea7bbef058e13dc2dd63490972ff847c31969ab5ec7c517
#   Stored in directory: /root/.cache/pip/wheels/a0/e5/04/a5fa9e60033548f205f0db5f6ab6f59cd27bd0da7f9c51cfe7
# Successfully built llama-cpp-python
# ...

# %%
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

# %%
model_name = "TheBloke/TinyLlama-1.1B-Chat-v0.3-GGUF"
model_file = "tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf"
HF_TOKEN = "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"
model_path = hf_hub_download(
               filename=model_file,
               local_dir='',
               token=HF_TOKEN,
               repo_id=model_name)
print("My model path: ", model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf:   0%|          | 0.00/668M [00:00<?, ?B/s]
# My model path:  tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf

# %%
# !./main -h
# Out:
# usage: ./main [options]
#
# options:
#   -h, --help            show this help message and exit
#   --version             show version and build info
#   -i, --interactive     run in interactive mode
#   --special             special tokens output enabled
#   --interactive-specials allow special tokens in user text, in interactive mode
#   --interactive-first   run in interactive mode and wait for input right away
#   -cnv, --conversation  run in conversation mode (does not print special tokens and suffix/prefix)
#   -ins, --instruct      run in instruction mode (use with Alpaca models)
#   -cml, --chatml        run in chatml mode (use with ChatML-compatible models)
#   --multiline-input     allows you to write or paste multiple lines without ending each in '\'
#   -r PROMPT, --reverse-prompt PROMPT
#                         halt generation at PROMPT, return control in interactive mode
#                         (can be specified more than once for multiple prompts).
# ...

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/cpu/llama.cpp/main

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf --n-predict 10
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716738718
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
cd /content/drive/MyDrive/lab_chen/gpu
# Out:
# /content/drive/MyDrive/lab_chen/gpu

# %%
# !git clone https://github.com/ggerganov/llama.cpp
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 25502, done.
# remote: Counting objects: 100% (6620/6620), done.
# remote: Compressing objects: 100% (344/344), done.
# remote: Total 25502 (delta 6429), reused 6327 (delta 6276), pack-reused 18882
# Receiving objects: 100% (25502/25502), 47.24 MiB | 13.04 MiB/s, done.
# Resolving deltas: 100% (18109/18109), done.
# Updating files: 100% (666/666), done.

# %%
cd /content/drive/MyDrive/lab_chen/gpu/llama.cpp
# Out:
# /content/drive/MyDrive/lab_chen/gpu/llama.cpp

# %%
# !make LLAMA_CUDA=1
# Out:
# I ccache not found. Consider installing it for faster compilation.
# I llama.cpp build info:
# I UNAME_S:   Linux
# I UNAME_P:   x86_64
# I UNAME_M:   x86_64
# I CFLAGS:    -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_LLAMAFILE -DGGML_USE_CUDA -I/usr/local/cuda/include -I/usr/local/cuda/targets/x86_64-linux/include -DGGML_CUDA_USE_GRAPHS  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion
# ...

# %%
# !pip install llama-cpp-python==0.1.78
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.1.78-cp310-cp310-linux_x86_64.whl size=296593 sha256=c64cff015ba3e94b5ef5d973df1cc3ae0d6173f2b8d38f98ecb8373b09d43ded
#   Stored in directory: /root/.cache/pip/wheels/61/f9/20/9ca660a9d3f2a47e44217059409478865948b5c8a1cba70030
# Successfully built llama-cpp-python
# ...

# %%
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

# %%
model_name = "TheBloke/TinyLlama-1.1B-Chat-v0.3-GGUF"
model_file = "tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf"
HF_TOKEN = "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"
model_path = hf_hub_download(
               filename=model_file,
               local_dir='',
               token=HF_TOKEN,
               repo_id=model_name)
print("My model path: ", model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf:   0%|          | 0.00/668M [00:00<?, ?B/s]
# My model path:  tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/gpu/llama.cpp/main

# %%
# !./main -m /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf --n-predict 10 --n-gpu-layers 12
# Out:
# Log start
# main: build = 3004 (dff451cf)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716739895
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
cd /content/drive/MyDrive/lab_chen/download
# Out:
# /content/drive/MyDrive/lab_chen/download

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import snapshot_download

# %%
model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
snapshot_download(
    repo_id=model_id,
    local_dir="/content/drive/MyDrive/lab_chen/download",
    local_dir_use_symlinks=False,
    revision="main",
    use_auth_token="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")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
cd /content/drive/MyDrive/lab_chen/cpu/llama.cpp
# Out:
# /content/drive/MyDrive/lab_chen/cpu/llama.cpp

# %%
# !pip install -r requirements.txt

# %%
# !python convert.py -h
# Out:
# usage: convert.py [-h] [--dump] [--dump-single] [--vocab-only] [--no-vocab]
#                   [--outtype {f32,f16,q8_0}] [--vocab-dir VOCAB_DIR] [--vocab-type VOCAB_TYPE]
#                   [--outfile OUTFILE] [--ctx CTX] [--concurrency CONCURRENCY] [--big-endian]
#                   [--pad-vocab] [--skip-unknown] [--verbose] [--metadata METADATA] [--get-outfile]
#                   model
#
# Convert a LLaMA model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file, or model file itself (*.pth, *.pt, *.bin)
#
# options:
#   -h, --help            show this help message and exit
#   --dump                don't convert, just show what's in the model
#   --dump-single         don't convert, just show what's in a single model file
#   --vocab-only          extract only the vocab
#   --no-vocab            store model without the vocab
#   --outtype {f32,f16,q8_0}
# ...

# %%
# !python convert.py /content/drive/MyDrive/lab_chen/download \
  --outfile tinyllama-1.1b-chat-v1.0.f16.gguf \
  --outtype f16
# Out:
# INFO:convert:Loading model file /content/drive/MyDrive/lab_chen/download/model.safetensors
# INFO:convert:model parameters count : 1100048384 (1B)
# INFO:convert:params = Params(n_vocab=32000, n_embd=2048, n_layer=22, n_ctx=2048, n_ff=5632, n_head=32, n_head_kv=4, n_experts=None, n_experts_used=None, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=10000.0, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyF16: 1>, path_model=PosixPath('/content/drive/MyDrive/lab_chen/download'))
# INFO:convert:Loaded vocab file PosixPath('/content/drive/MyDrive/lab_chen/download/tokenizer.model'), type 'spm'
# INFO:convert:Vocab info: <SentencePieceVocab with 32000 base tokens and 0 added tokens>
# INFO:convert:Special vocab info: <SpecialVocab with 0 merges, special tokens {'bos': 1, 'eos': 2, 'unk': 0, 'pad': 2}, add special tokens unset>
# INFO:convert:Writing tinyllama-1.1b-chat-v1.0.f16.gguf, format 1
# ...

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/cpu/llama.cpp/main

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf --n-predict 10
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716740664
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
cd /content/drive/MyDrive/lab_chen/gpu/llama.cpp
# Out:
# /content/drive/MyDrive/lab_chen/gpu/llama.cpp

# %%
# !pip install -r requirements.txt

# %%
# !python convert.py -h
# Out:
# usage: convert.py [-h] [--dump] [--dump-single] [--vocab-only] [--no-vocab]
#                   [--outtype {f32,f16,q8_0}] [--vocab-dir VOCAB_DIR] [--vocab-type VOCAB_TYPE]
#                   [--outfile OUTFILE] [--ctx CTX] [--concurrency CONCURRENCY] [--big-endian]
#                   [--pad-vocab] [--skip-unknown] [--verbose] [--metadata METADATA] [--get-outfile]
#                   model
#
# Convert a LLaMA model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file, or model file itself (*.pth, *.pt, *.bin)
#
# options:
#   -h, --help            show this help message and exit
#   --dump                don't convert, just show what's in the model
#   --dump-single         don't convert, just show what's in a single model file
#   --vocab-only          extract only the vocab
#   --no-vocab            store model without the vocab
#   --outtype {f32,f16,q8_0}
# ...

# %%
# !python convert.py /content/drive/MyDrive/lab_chen/download \
  --outfile tinyllama-1.1b-chat-v1.0.f16.gguf \
  --outtype f16
# Out:
# INFO:convert:Loading model file /content/drive/MyDrive/lab_chen/download/model.safetensors
# INFO:convert:model parameters count : 1100048384 (1B)
# INFO:convert:params = Params(n_vocab=32000, n_embd=2048, n_layer=22, n_ctx=2048, n_ff=5632, n_head=32, n_head_kv=4, n_experts=None, n_experts_used=None, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=10000.0, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyF16: 1>, path_model=PosixPath('/content/drive/MyDrive/lab_chen/download'))
# INFO:convert:Loaded vocab file PosixPath('/content/drive/MyDrive/lab_chen/download/tokenizer.model'), type 'spm'
# INFO:convert:Vocab info: <SentencePieceVocab with 32000 base tokens and 0 added tokens>
# INFO:convert:Special vocab info: <SpecialVocab with 0 merges, special tokens {'bos': 1, 'eos': 2, 'unk': 0, 'pad': 2}, add special tokens unset>
# INFO:convert:Writing tinyllama-1.1b-chat-v1.0.f16.gguf, format 1
# ...

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/gpu/llama.cpp/main

# %%
# !./main -m /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf --n-predict 10 --n-gpu-layers 12
# Out:
# Log start
# main: build = 3004 (dff451cf)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716741547
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
cd /content/drive/MyDrive/lab_chen/cpu/llama.cpp
# Out:
# /content/drive/MyDrive/lab_chen/cpu/llama.cpp

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/cpu/llama.cpp/quantize

# %%
# !./quantize /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf Q8_0
# Out:
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: quantizing '/content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf' to '/content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf' as Q8_0
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf --n-predict 10
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716744818
# llama_model_loader: loaded meta data with 23 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
cd /content/drive/MyDrive/lab_chen/gpu/llama.cpp
# Out:
# /content/drive/MyDrive/lab_chen/gpu/llama.cpp

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/gpu/llama.cpp/quantize

# %%
# !./quantize /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf Q8_0
# Out:
# main: build = 3004 (dff451cf)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: quantizing '/content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf' to '/content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf' as Q8_0
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# ...

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/gpu/llama.cpp/main

# %%
# !./main -m /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf --n-predict 10 --n-gpu-layers 12
# Out:
# Log start
# main: build = 3004 (dff451cf)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716745504
# llama_model_loader: loaded meta data with 23 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/gpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
cd /content/drive/MyDrive/lab_chen/cpu/llama.cpp
# Out:
# /content/drive/MyDrive/lab_chen/cpu/llama.cpp

# %%
# !chmod 755 /content/drive/MyDrive/lab_chen/cpu/llama.cpp/main

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf --interactive
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716783492
# llama_model_loader: loaded meta data with 23 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.Q8_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf -p "What is the capital city of France? A. Rome B. Berlin C. Paris D. Madrid Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716749923
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf -p "What is the chemical symbol for water? A. O2 B. CO2 C. H2O D. H2 Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716750002
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf -p "Who painted the Mona Lisa? A. Leonardo da Vinci B. Pablo Picasso C. Vincent van Gogh D. Michelangelo Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716750210
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf --interactive
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716750533
# llama_model_loader: loaded meta data with 22 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v1.0.f16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = download
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 32000
# llama_model_loader: - kv   3:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 2048
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "What is the capital city of France? A. Rome B. Berlin C. Paris D. Madrid Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716751966
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "What is the chemical symbol for water? A. O2 B. CO2 C. H2O D. H2 Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716752097
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "Who painted the Mona Lisa? A. Leonardo da Vinci B. Pablo Picasso C. Vincent van Gogh D. Michelangelo Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716752503
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "What is the powerhouse of the cell? A. Mitochondria B. Ribosome C. Nucleus D. Golgi apparatus Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716752615
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "Who wrote Romeo and Juliet? A. William Shakespeare B. Jane Austen C. Charles Dickens D. Mark Twain Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716753007
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "What is the tallest mountain in the world? A. K2 B. Mount Kilimanjaro C. Mount Everest D. Mount Fuji Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716753243
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "What is the chemical symbol for gold? A. Au B. Ag C. Pt D. Cu Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716753487
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "Which planet is known as the Red Planet? A. Jupiter B. Mars C. Venus D. Saturn Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716753817
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "What is the largest ocean on Earth? A. Atlantic Ocean B. Indian Ocean C. Arctic Ocean D. Pacific Ocean Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716753977
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...

# %%
# !./main -m /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf -p "What is the chemical symbol for iron? A. Ir B. Fe C. In D. Io Answer:"
# Out:
# Log start
# main: build = 3003 (d298382a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1716754019
# llama_model_loader: loaded meta data with 20 key-value pairs and 201 tensors from /content/drive/MyDrive/lab_chen/cpu/llama.cpp/tinyllama-1.1b-chat-v0.3.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = py007_tinyllama-1.1b-chat-v0.3
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# ...
